# %%
import pandas as pd
import os 

ruta= "C:\\Users\\ralphy.nunezmercado\\Downloads"

def concatenar_df(archivo,ruta):
    ruta = os.path.join(ruta,archivo)
    dataframe = pd.read_csv(ruta)
    return dataframe    
    

total_df = pd.concat([concatenar_df("acoruna.csv",ruta),concatenar_df("lugo.csv",ruta),concatenar_df("ourense.csv",ruta),concatenar_df("pontevedra.csv",ruta)])

total_df[['Código','Concello','Provincia']]
# Out:
#        Código                       Concello   Provincia
# 0    15000016                       Abegondo    A Coruña
# 1    15000107                           Ames    A Coruña
# 2    15000132                           Ames    A Coruña
# 3    15000338                           Ares    A Coruña
# 4    15000363                        Arteixo    A Coruña
# 5    15000545                       A Coruña    A Coruña
# 6    15000569                        Arteixo    A Coruña
# 7    15000600                          Arzúa    A Coruña
# 8    15000612                          Arzúa    A Coruña
# 9    15001033                       Bergondo    A Coruña
# 10   15001070                       Bergondo    A Coruña
# 11   15001112                       Betanzos    A Coruña
# 12   15001124                       Betanzos    A Coruña
# 13   15001136                       Betanzos    A Coruña
# 14   15001148                       Betanzos    A Coruña
# ...
