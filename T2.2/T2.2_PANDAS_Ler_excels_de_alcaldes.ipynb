# %% [markdown]
# # T2.2: PANDAS. Ler excels de alcaldes

# %% [markdown]
# <p>Instalación de paquetes necesarios</p>

# %%
# %conda install pandas # o  %pip install pandas
# %conda install datetime #o %pip install datetime
# %conda install unidecode # o %pip install unidecode

# %% [markdown]
# <p>Importar librerías</p>

# %%
import pandas as pd
from datetime import datetime
from unidecode import unidecode

# %% [markdown]
# ### Normalización del data frame
# <p>Cargo todas las páginas del excel y creo el método para limpiar y formatear los datos, después volvemos a juntar las hojas limpiadas.</p>

# %%
excel_entero = pd.read_excel("Alcades_1979_2023.xlsx", na_values='\\N', sheet_name=None)

def limpiar(df): 
    # Quitar los valores NaN
    df = df.dropna(axis=1, how='all') 

    # Quitar las columnas innecesarias
    df = df.iloc[7:]

    # Quitar una columna vacía
    df = df.drop(['Unnamed: 13'], axis=1) 

    # Renombrar  los header
    df.rename(columns={'Unnamed: 3': 'COMUNIDAD AUTONOMA', 'Unnamed: 4': 'PROVINCIA', 'Unnamed: 5': 'MUNICIPIO', 'Unnamed: 6': 'CODIGO INE', 'Unnamed: 7': 'NOMBRE', 'Unnamed: 8': 'LISTA', 'Unnamed: 9': 'FECHA POSESION', 'Unnamed: 10': 'FECHA BAJA'}, inplace=True)
    

    # Eliminar las filas donde el nombre este vacío
    df = df[df['NOMBRE'].notna() & (df['NOMBRE'] != '')]


    # Cambiar el formato de la fecha 
    for fecha_col in ['FECHA POSESION', 'FECHA BAJA']: 
        if fecha_col in df.columns:
            df[fecha_col] = pd.to_datetime(df[fecha_col], errors='coerce', dayfirst=True, format="%d/%m/%Y").dt.strftime('%d/%m/%Y')

    # Quitar los  acentos y convertirlo a minuscula
    df = df.map(lambda texto: unidecode(
        texto.lower().strip()
        .replace(',', '')
        .replace('.', '')
        .replace('*', '')
        .replace('-', ' ')) 
        if isinstance(texto, str) else texto)

    return df 

hojas_limpiadas = []

# Limpiar las hojas y concatenarlas en un solo Dataframe
for hoja in excel_entero:
    hoja_limpiada = limpiar(excel_entero[hoja])  
    hojas_limpiadas.append(hoja_limpiada)  
    

excel_entero_df = pd.concat(hojas_limpiadas, ignore_index=True)



excel_entero_df.head(50)
# Out:
#    COMUNIDAD AUTONOMA PROVINCIA             MUNICIPIO CODIGO INE  \
# 0           andalucia   almeria                  abla     040010
# 1           andalucia   almeria              abrucena     040025
# 2           andalucia   almeria                  adra     040031
# 3           andalucia   almeria             albanchez     040046
# 4           andalucia   almeria             alboloduy     040059
# 5           andalucia   almeria                 albox     040062
# 6           andalucia   almeria               alcolea     040078
# 7           andalucia   almeria              alcontar     040084
# 8           andalucia   almeria  alcudia de monteagud     040097
# 9           andalucia   almeria               alhabia     040101
# 10          andalucia   almeria     alhama de almeria     040118
# 11          andalucia   almeria                alicun     040123
# 12          andalucia   almeria               almeria     040139
# 13          andalucia   almeria              almocita     040144
# 14          andalucia   almeria               alsodux     040157
# 15          andalucia   almeria                 antas     040160
# 16          andalucia   almeria              arboleas     040176
# 17          andalucia   almeria   armuna de almanzora     040182
# 18          andalucia   almeria               bacares     040195
# 19          andalucia   almeria              bayarcal     040209
# 20          andalucia   almeria              bayarque     040216
# 21          andalucia   almeria                 bedar     040221
# 22          andalucia   almeria                beires     040237
# 23          andalucia   almeria             benahadux     040242
# 24          andalucia   almeria               beninar     04025d
# 25          andalucia   almeria             benitagla     040268
# 26          andalucia   almeria             benizalon     040274
# 27          andalucia   almeria            bentarique     040280
# 28          andalucia   almeria                 berja     040293
# 29          andalucia   almeria              canjayar     040307
# 30          andalucia   almeria              cantoria     040314
# 31          andalucia   almeria            carboneras     040329
# 32          andalucia   almeria    castro de filabres     040335
# 33          andalucia   almeria               chercos     040366
# 34          andalucia   almeria              chirivel     040372
# 35          andalucia   almeria                cobdar     040340
# 36          andalucia   almeria  cuevas del almanzora     040353
# 37          andalucia   almeria                dalias     040388
# 38          andalucia   almeria                dalias     040388
# 39          andalucia   almeria                dalias     040388
# 40          andalucia   almeria              darrical     040391
# 41          andalucia   almeria            ejido (el)     049026
# 42          andalucia   almeria                  enix     040412
# 43          andalucia   almeria                 felix     040433
# 44          andalucia   almeria                 fines     040448
# 45          andalucia   almeria                finana     040451
# 46          andalucia   almeria                fondon     040464
# 47          andalucia   almeria                 gador     040470
# 48          andalucia   almeria       gallardos (los)     040486
# 49          andalucia   almeria              garrucha     040499
#
#                             NOMBRE  LISTA FECHA POSESION  FECHA BAJA
# 0      herrerias herrerias antonio    ucd     19/04/1979         NaN
# 1                martinez lao juan   psoe     19/04/1979         NaN
# 2           sarmiento posada pedro  otros     19/04/1979         NaN
# 3               martos aybar ramon    ucd     19/04/1979         NaN
# 4          blanes paniagua mariano    ucd     19/04/1979         NaN
# 5              miras carrasco jose    ucd     19/04/1979         NaN
# 6   lopez mellado gabriel bernardo    ucd     19/04/1979         NaN
# 7          requena martinez manuel    ucd     19/04/1979         NaN
# 8            perez padilla rogelio    ucd     19/04/1979         NaN
# 9         castellon diaz francisco    ucd     19/04/1979         NaN
# 10       picon garcia jose antonio    ind     19/04/1979         NaN
# 11          gonzalez martinez juan    ind     19/04/1979         NaN
# 12      martinez cabrejas santiago   psoe     19/04/1979         NaN
# 13             compan ruiz esteban    ucd     19/04/1979         NaN
# 14            gonzalez molina luis    ucd     19/04/1979         NaN
# 15         perez casquet francisco    ucd     20/04/1979         NaN
# 16         mellado parra francisco    ucd     19/04/1979         NaN
# 17     lorente canabate juan pedro    ucd     19/04/1979         NaN
# 18               egea golbano juan    ucd     19/04/1979         NaN
# 19         ocana utrilla francisco    ucd     19/04/1979         NaN
# 20               lopez mateo julio    ucd     19/04/1979         NaN
# 21            gonzalez jodar gines    ucd     20/04/1979         NaN
# 22         garcia valverde teodoro    ucd     19/04/1979         NaN
# 23           rodriguez segura jose    pce     19/04/1979         NaN
# 24           fernandez campoy juan    ucd     19/04/1979         NaN
# 25            padilla sanchez juan    ucd     19/04/1979         NaN
# 26             carrique lopez jose    ucd     19/04/1979         NaN
# 27       romera nieto jose antonio   psoe     19/04/1979         NaN
# 28          moreno ferron federico    ucd     19/04/1979         NaN
# 29            romera granados jose    ucd     19/04/1979         NaN
# 30         gea guerrero juan pedro    ucd     19/04/1979         NaN
# 31         alonso aguado sebastian  otros     26/05/1979         NaN
# 32       martinez martinez serafin    ind     19/04/1979         NaN
# 33            saez soriano antonio    ucd     19/04/1979         NaN
# 34          garcia ramos francisco    ind     19/04/1979         NaN
# 35      yepes hernandez bernardino   psoe     20/04/1979         NaN
# 36                 soler mula juan    ucd     20/04/1979         NaN
# 37       garcia acien jose antonio    ucd     30/07/1982  20/11/1982
# 38           martin maldonado luis   psoe     19/04/1979  30/07/1982
# 39           maldonado criado jose  cgest     20/11/1982         NaN
# 40              catena castro jose   psoe     19/04/1979         NaN
# 41       garcia acien jose antonio    ucd     30/07/1982         NaN
# 42      martinez fernandez antonio    ucd     20/04/1979         NaN
# 43          garcia lopez francisco   psoe     19/04/1979         NaN
# 44     sanchez sanchez jose manuel   psoe     19/04/1979         NaN
# 45             gomez martinez luis    ucd     20/04/1979         NaN
# 46          lopez lozano baldomero    ucd     20/04/1979         NaN
# 47            manas rodriguez jose    ucd     20/04/1979         NaN
# 48           garcia molina antonio    ucd     20/04/1979         NaN
# 49              perez lopez adolfo    ucd     20/04/1979         NaN

# %% [markdown]
# ### Fai algunhas averiguacións sobre os datos:
#
# <p>1. Saber qué alcaldes repetiron mandato e en qué lexislaturas (ollo, poden mudar un pouco os nomes).</p>

# %%
import pandas as pd

# Agrupar por nombre y municipio, y contar las legislaturas
repetidos = (
    excel_entero_df.groupby(['NOMBRE', 'MUNICIPIO'])
    .size()
    .reset_index(name='FRECUENCIA')
)

# Filtrar alcaldes que repitieron mandato 
alcaldes_repetidos = repetidos[repetidos['FRECUENCIA'] > 1]

# Filtrar el dataframe original para incluir solo alcaldes que repitieron mandato
df_repetidos = excel_entero_df.merge(alcaldes_repetidos, on=['NOMBRE', 'MUNICIPIO'])

# Convertir las fechas de posesión a formato datetime y extraer solo los años
df_repetidos['FECHA POSESION'] = pd.to_datetime(df_repetidos['FECHA POSESION'], errors='coerce', dayfirst=True)
df_repetidos = df_repetidos.dropna(subset=['FECHA POSESION'])  # Eliminar fechas inválidas

# Agrupar por nombre y municipio, y extraer las legislaturas (años) únicos en los que participaron
legislatura_por_alcalde = (
    df_repetidos.groupby(['NOMBRE', 'MUNICIPIO'])['FECHA POSESION']
    .apply(lambda x: sorted(x.dt.year.unique()))
    .reset_index(name='LEGISLATURAS')
)

# Filtrar solo los alcaldes que participaron en más de una legislatura
legislatura_por_alcalde = legislatura_por_alcalde[legislatura_por_alcalde['LEGISLATURAS'].apply(len) > 1]

# Mostrar resultados
legislatura_por_alcalde
# Out:
#                           NOMBRE               MUNICIPIO  \
# 0          abad becquer fernando                 leganes
# 1         abad benedicto enrique          rinconada (la)
# 2            abad caballero jose              carabantes
# 3            abad garcia antonio  santa cruz de marchena
# 4             abad gomez heradio     poblacion de campos
# ...                          ...                     ...
# 21390  zuniga perez lemaur jesus   rozas de madrid (las)
# 21391    zurbano lecumberri jose                 cabredo
# 21392        zuriaga adrian blas               yesa (la)
# 21393     zurriaga manez vicente                  olocau
# 21394      zurro calvo esmeraldo              granucillo
#
#                    LEGISLATURAS
# 0                  [1983, 1987]
# 1      [1987, 1991, 1995, 1999]
# 2                  [1983, 1987]
# 3            [1991, 1995, 1999]
# 4            [1979, 1983, 1991]
# ...                         ...
# 21390        [1983, 1987, 1991]
# 21391  [1979, 1983, 1991, 1997]
# 21392              [1979, 1991]
# 21393              [1979, 1983]
# 21394              [1987, 1991]
#
# [21309 rows x 3 columns]

# %% [markdown]
# <p>2. De repetir mandato. Qué partidos políticos tiveron máis éxito? Qué alcaldes mudaron de partido?</p>

# %%
# Contar cuántas veces cada partido tuvo alcaldes reelectos
partidos_exito = df_repetidos.groupby('LISTA').size().reset_index(name='ALCALDES REELECTOS')

# Ordenar de mayor a menor
partidos_exito = partidos_exito.sort_values(by='ALCALDES REELECTOS', ascending=False)

print("Partidos más exitosos: ")
print(partidos_exito)


# Agrupar por alcalde y municipio para obtener los partidos únicos en los que ha estado
cambios_partido = (
    df_repetidos.groupby(['NOMBRE', 'MUNICIPIO'])['LISTA']
    .apply(lambda x: sorted(x.unique()))
    .reset_index(name='LISTA')
)

# Filtrar solo los alcaldes que han cambiado de partido.
cambios_partido = cambios_partido[cambios_partido['LISTA'].apply(len) > 1]


print("Cambios de partido: ")
# Mostrar resultados
cambios_partido
# Out:
# Partidos más exitosos:
#       LISTA  ALCALDES REELECTOS
# 71     psoe               19553
# 62       pp               18729
# 47      ind                3325
# 25      ciu                2962
# 51    otros                1818
# ..      ...                 ...
# 69      psg                   1
# 30       cs                   1
# 61  podemos                   1
# 43  ganemos                   1
# 34       ee                   1
#
# [89 rows x 2 columns]
# Cambios de partido:
#                                    NOMBRE             MUNICIPIO  \
# 2                     abad caballero jose            carabantes
# 4                      abad gomez heradio   poblacion de campos
# 5                     abad pastor eugenio         cabra de mora
# 7                      abad roldan amadeo  congosto de valdavia
# 9                   abadia urieta armando                  jaca
# ...                                   ...                   ...
# 21386     zubizarreta lasagabaster xabier  arrasate o mondragon
# 21388  zunbeltz bedialauneta ibaibarriaga              ondarroa
# 21391             zurbano lecumberri jose               cabredo
# 21392                 zuriaga adrian blas             yesa (la)
# 21394               zurro calvo esmeraldo            granucillo
#
#                           LISTA
# 2               [ap, ap/pdp/ul]
# 4          [ap/pdp/ul, pp, ucd]
# 5              [ap/pdp/ul, ind]
# 7                     [pp, ucd]
# 9      [ap, ap/pdp/ul, pp, ucd]
# ...                         ...
# 21386                  [eh, hb]
# 21388         [bildu, bildu ea]
# 21391         [cgest, ind, upn]
# 21392                 [pp, ucd]
# 21394              [pp, uc cds]
#
# [6597 rows x 3 columns]

# %% [markdown]
# <p>3. Cantos alcaldes cesaron antes de tempo?</p>

# %%
# Convertir las fechas a formato datetime
excel_entero_df['FECHA POSESION'] = pd.to_datetime(excel_entero_df['FECHA POSESION'], errors='coerce',dayfirst=True)
excel_entero_df['FECHA BAJA'] = pd.to_datetime(excel_entero_df['FECHA BAJA'], errors='coerce',dayfirst=True)

# Calcular la duración del mandato en años
excel_entero_df['DURACION'] = (excel_entero_df['FECHA BAJA'] - excel_entero_df['FECHA POSESION']).dt.days / 365

# Filtrar los  alcaldes que cesaron antes de 4 años
ceses_anticipados = excel_entero_df[excel_entero_df['DURACION'] < 4]


total_cesados = ceses_anticipados.shape[0]

print(f"Total de alcaldes que cesaron antes de tiempo: {total_cesados}")
# Out:
# Total de alcaldes que cesaron antes de tiempo: 6476

# %% [markdown]
# <p>4. Cal é o soldo máis alto e de que alcaldes?</p>

# %%
ultima_hoja_df = limpiar(excel_entero["Alcaldes 2019-2023"])

retribuciones2018_df = pd.read_csv("tabula-retribuciones_alcaldes_2021.csv")

# Convertir la columna 'TOTAL PERCIBIDO' a float para poder obtener el sueldo de los alcaldes
retribuciones2018_df["TOTAL PERCIBIDO"] = (
    retribuciones2018_df["TOTAL PERCIBIDO"]
    .str.replace(".", "", regex=False) 
    .str.replace(",", ".", regex=False) 
    .astype(float)
)

# Normalizar las columnas
retribuciones2018_df[["AYUNTAMIENTO", "PROVINCIA"]] = retribuciones2018_df[["AYUNTAMIENTO", "PROVINCIA"]].map(lambda x: unidecode(x.lower().strip()) if isinstance(x, str) else x)


# Hacer el merge con los nombres normalizados
df_merged = ultima_hoja_df.merge(
    retribuciones2018_df,
    left_on=["MUNICIPIO", "PROVINCIA"],
    right_on=["AYUNTAMIENTO", "PROVINCIA"]
    )

# Seleccionar columnas necesarias
df_ordenado = df_merged[["NOMBRE", "MUNICIPIO", "PROVINCIA", "TOTAL PERCIBIDO"]]

# Ordenar por sueldo de mayor a menor
df_ordenado = df_ordenado.sort_values(by="TOTAL PERCIBIDO", ascending=False)

print("Top 10 alcaldes con mayor sueldo: ")
df_ordenado.head(10)
# Out:
# Top 10 alcaldes con mayor sueldo:
#                                     NOMBRE   MUNICIPIO          PROVINCIA  \
# 5824  jose luis martinez almeida navasques      madrid             madrid
# 4133                     ada colau ballano   barcelona          barcelona
# 6302                juan maria aburto rike      bilbao            bizkaia
# 634                     juan espadas cejas     sevilla            sevilla
# 635                 antonio munoz martinez     sevilla            sevilla
# 3215                 oscar puente santiago  valladolid         valladolid
# 5253                       joan ribo canut    valencia  valencia/valencia
# 6323                    amaia agirre munoa       getxo            bizkaia
# 12      ramon fernandez pacheco monterreal     almeria            almeria
# 13            maria del mar vazquez aguero     almeria            almeria
#
#       TOTAL PERCIBIDO
# 5824        108517.80
# 4133        100000.04
# 6302         98018.40
# 634          88673.68
# 635          88673.68
# 3215         87595.62
# 5253         87137.82
# 6323         83985.57
# 12           83376.86
# 13           83376.86

# %% [markdown]
# <p>5. Relaciona os soldos altos e baixos coa "probabilidade" de repetir mandato.</p>

# %%
# Dire que un sueldo bajo es por debajo del SMI ANUAL actualmente: 15876

"""retribuciones2018_dfalto =  

retribuciones2018_dfalto"""

retribuciones2018_df['TOTAL PERCIBIDO'] 

df_merged = ultima_hoja_df.merge(
    retribuciones2018_df,
    left_on=["MUNICIPIO", "PROVINCIA"],
    right_on=["AYUNTAMIENTO", "PROVINCIA"]
    )

df_merged
# Out:
#      COMUNIDAD AUTONOMA PROVINCIA   MUNICIPIO CODIGO INE  \
# 0             andalucia   almeria        abla     040010
# 1             andalucia   almeria    abrucena     040025
# 2             andalucia   almeria        adra     040031
# 3             andalucia   almeria   albanchez     040046
# 4             andalucia   almeria   alboloduy     040059
# ...                 ...       ...         ...        ...
# 6433         pais vasco  gipuzkoa   zumarraga     200809
# 6434         pais vasco  gipuzkoa  baliarrain     209040
# 6435         pais vasco  gipuzkoa  baliarrain     209040
# 6436         pais vasco  gipuzkoa  baliarrain     209040
# 6437         pais vasco  gipuzkoa  baliarrain     209040
#
#                              NOMBRE  LISTA FECHA POSESION  FECHA BAJA  \
# 0           antonio fernandez lopez     pp     15/06/2019         NaN
# 1               ismael gil salmeron   psoe     15/06/2019         NaN
# 2               manuel cortes perez     pp     15/06/2019         NaN
# 3                amador lopez pardo    c's     15/06/2019         NaN
# 4          sonia maria guil soriano     pp     15/06/2019         NaN
# ...                             ...    ...            ...         ...
# 6433        mikel serrano aperribay   psoe     15/06/2019         NaN
# 6434        jaione olano etxeberria  otros     19/05/2020  21/03/2021
# 6435          juan ma iturrioz goni  otros     21/03/2021  13/03/2022
# 6436           andoni olano manzano  otros     13/03/2022  15/11/2022
# 6437  ma victoria gamendia oyarbide  otros     15/11/2022         NaN
#
#      AYUNTAMIENTO        CCAA RÉGIMEN DEDICACIÓN  TOTAL PERCIBIDO
# 0            abla   Andalucía          Exclusiva         30356.62
# 1        abrucena   Andalucía          Exclusiva         34270.18
# 2            adra   Andalucía          Exclusiva         57584.20
# 3       albanchez   Andalucía          Exclusiva         23572.48
# 4       alboloduy   Andalucía            Parcial         24300.04
# ...           ...         ...                ...              ...
# 6433    zumarraga  País Vasco          Exclusiva         65697.80
# 6434   baliarrain  País Vasco     Sin dedicación             0.00
# 6435   baliarrain  País Vasco     Sin dedicación             0.00
# 6436   baliarrain  País Vasco     Sin dedicación             0.00
# 6437   baliarrain  País Vasco     Sin dedicación             0.00
#
# [6438 rows x 12 columns]

# %% [markdown]
# <p>6. Outra información interesante.</p>
